# %% [markdown]
# # Print Model Tree

# %%
# %matplotlib inline

from sklearn.tree import plot_tree
import pickle

model = None
with open("../resources/model.pckl", "rb") as file:
    model = pickle.load(file)
    
plot_tree(model, fontsize=12)
# Out:
# [Text(133.92000000000002, 181.2, 'X[5] <= 0.5\ngini = 0.667\nsamples = 203\nvalue = [67.667, 67.667, 67.667]'),
#  Text(66.96000000000001, 108.72, 'gini = 0.5\nsamples = 163\nvalue = [0.0, 56.149, 55.841]'),
#  Text(200.88000000000002, 108.72, 'X[0] <= 0.5\ngini = 0.414\nsamples = 40\nvalue = [67.667, 11.518, 11.825]'),
#  Text(133.92000000000002, 36.23999999999998, 'gini = 0.126\nsamples = 13\nvalue = [67.667, 2.16, 2.628]'),
#  Text(267.84000000000003, 36.23999999999998, 'gini = 0.5\nsamples = 27\nvalue = [0.0, 9.358, 9.197]')]
